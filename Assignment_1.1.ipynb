# %% [markdown]
# # QUESTION AND ANSWERS

# %%
#1. In the below elements which of them are values or an expression? 
#eg:- values can be integer or string and expressions will be mathematical operators.
#  * , 'hello', -87.8,  -,  / , +, 6. 

# Answer: *, -,  / , +: these are Expressions and 'hello', 6, -87.8: these are values. 



#2. What is the difference between string and variable?

# Answer: A string can be defined in python with quotation marks or double quotation marks.
          # We can assign a string to a variable.
    # Whereas a variable can be defined as a name which is used to refer memory location which stores values of any data type.
    

    
    
#3. Describe three different data types.

# Answer: 1. Number: It is a numberic value which can be used to perform mathematical caluculations may be an interger or float
         #2. Boolen: It is defined with 2 values True or False (0 or 1) which can be used to find out whether the given statement is true or false.
         #3. Set: Set. A Set in python is an unordered collection of the data type. 
         #It is iterable and mutable and has unique elements.

            
            
#4. What is an expression made up of? What do all expressions do?

#Answer: An expression is any combination of symbols like a variable, constants, and operators representing a value to be evaluted. 
        #It should have one or more operators and at least one operand like variable or constant.

    
    

#5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# Answer: The assignment statements doesn't have any operators included as there will be an constant assigned value to it.
        # Where as the expression is combination of constants with operators which gives a value on caluculating in the end.

    

#6. After running the following code, what does the variable bacon contain? :bacon = 22, bacon + 1

#Answer: 23


#7. What should the values of the following two terms be? :'spam' + 'spamspam','spam' * 3

#Answer:  ('spamspamspam', 'spamspamspam')



#8. Why is eggs a valid variable name while 100 is invalid?

#Answer: We can assign an alphabet or a word as a variable name which can store a numberic data. Variable names don't start with number in python
        #But 100 is numeric value which is equal to itself and will not allow to store any other variable constants.

    
    
#9. What three functions can be used to get the integer, floating-point number, or string version of a value?

#Answer: The int(), float(), and str() functions will evaluate to the integer, floating-point number.
         #The string versions of the value passed to them.
    
    

#10. Why does this expression cause an error? How can you fix it?
#'I have eaten ' + 99 + ' burritos.'

#Answer: This expression causes an error as the string can only be concatenated with a string.

# This can be fixed with this expression: 'I have eaten ' + '99' + ' burritos.'
